# %%
import os
import glob
import gensim
from gensim import corpora
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
import pandas as pd


# Download NLTK stopwords if not already done
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/nishithreddy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/nishithreddy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
data_dir = "./test/"  

# Load transcripts
files = glob.glob(os.path.join(data_dir, "*.txt"))
documents = []

# %%
for file_path in files:
    with open(file_path, "r", encoding="utf-8") as f:
        text = f.read()
        documents.append(text)

# %%
stop_words = set(stopwords.words("english"))
def preprocess(text):
    tokens = word_tokenize(text.lower())
    tokens = [t for t in tokens if t.isalpha() and t not in stop_words]
    return tokens

# %%
texts = [preprocess(doc) for doc in documents]
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
# Train LDA model
num_topics = 15  # you can tune this
lda_model = gensim.models.LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=num_topics,
    random_state=42,
    passes=10,
    alpha='auto'
)

# %%
# Print the topics
print("\nGlobal Topics:")
for i, topic in lda_model.show_topics(num_topics=num_topics, num_words=8, formatted=False):
    print(f"Topic {i}: {[word for word, _ in topic]}")
# Out:
# Global Topics:
# Topic 0: ['really', 'like', 'things', 'know', 'lot', 'used', 'people', 'think']
# Topic 1: ['andrews', 'people', 'research', 'kind', 'time', 'work', 'forest', 'get']
# Topic 2: ['climate', 'think', 'health', 'like', 'really', 'one', 'change', 'work']
# Topic 3: ['well', 'know', 'would', 'people', 'go', 'said', 'one', 'get']
# Topic 4: ['know', 'people', 'one', 'think', 'time', 'would', 'like', 'well']
# Topic 5: ['think', 'like', 'climate', 'people', 'get', 'know', 'really', 'going']
# Topic 6: ['like', 'people', 'one', 'know', 'would', 'really', 'lot', 'think']
# Topic 7: ['said', 'know', 'got', 'one', 'go', 'going', 'yeah', 'like']
# Topic 8: ['one', 'people', 'students', 'get', 'would', 'time', 'think', 'school']
# Topic 9: ['history', 'observational', 'natural', 'question', 'think', 'know', 'time', 'science']
# Topic 10: ['forest', 'think', 'would', 'people', 'yeah', 'going', 'really', 'right']
# Topic 11: ['like', 'know', 'really', 'think', 'people', 'would', 'yeah', 'lot']
# Topic 12: ['yeah', 'forest', 'think', 'andrews', 'well', 'know', 'like', 'research']
# Topic 13: ['know', 'one', 'think', 'came', 'time', 'people', 'years', 'went']
# Topic 14: ['think', 'lot', 'time', 'work', 'coastal', 'like', 'washington', 'would']

# %%
# Get topic distribution per transcript
print("\nPer-transcript topic distributions:")
for i, bow in enumerate(corpus):
    topic_probs = lda_model.get_document_topics(bow)
    print(f"Transcript {i+1} ({os.path.basename(files[i])}): {topic_probs}")
# Out:
# Per-transcript topic distributions:
# Transcript 1 (34626.txt): [(1, np.float32(0.39001068)), (7, np.float32(0.50932324)), (10, np.float32(0.042088628)), (11, np.float32(0.058416758))]
# Transcript 2 (35538.txt): [(11, np.float32(0.9998669))]
# Transcript 3 (30871.txt): [(4, np.float32(0.5013479)), (7, np.float32(0.08184737)), (8, np.float32(0.37927026)), (11, np.float32(0.03351583))]
# Transcript 4 (34961.txt): [(4, np.float32(0.019559208)), (11, np.float32(0.98025787))]
# Transcript 112 (35385.txt): [(0, np.float32(0.032559864)), (7, np.float32(0.025440184)), (11, np.float32(0.9412097))]
# Transcript 113 (35353.txt): [(5, np.float32(0.01370669)), (10, np.float32(0.7910544)), (11, np.float32(0.18515722))]
# Transcript 114 (35409.txt): [(4, np.float32(0.9561131)), (11, np.float32(0.043783657))]
# Transcript 115 (35384.txt): [(7, np.float32(0.020405551)), (11, np.float32(0.9795284))]
# Transcript 116 (34501.txt): [(1, np.float32(0.13812186)), (12, np.float32(0.85982376))]
# Transcript 117 (31041.txt): [(4, np.float32(0.12510456)), (11, np.float32(0.8720121))]
# Transcript 118 (35541.txt): [(11, np.float32(0.99980265))]
# Transcript 119 (34846.txt): [(7, np.float32(0.0350669)), (10, np.float32(0.96453655))]
# Transcript 120 (34661.txt): [(1, np.float32(0.3226048)), (4, np.float32(0.29870617)), (10, np.float32(0.28836188)), (12, np.float32(0.0894916))]
# Transcript 121 (34891.txt): [(1, np.float32(0.015231318)), (10, np.float32(0.9846692))]
# Transcript 122 (35543.txt): [(11, np.float32(0.9998483))]
# Transcript 123 (30981.txt): [(11, np.float32(0.9996288))]
# Transcript 124 (35386.txt): [(4, np.float32(0.42688292)), (5, np.float32(0.025998421)), (10, np.float32(0.07285316)), (11, np.float32(0.47398552))]
# Transcript 125 (34701.txt): [(1, np.float32(0.17092678)), (4, np.float32(0.13115208)), (5, np.float32(0.036121294)), (7, np.float32(0.41195363)), (10, np.float32(0.2475145))]
# Transcript 126 (35437.txt): [(4, np.float32(0.42915735)), (7, np.float32(0.5537903))]
# Transcript 127 (35387.txt): [(4, np.float32(0.2604224)), (7, np.float32(0.18317449)), (11, np.float32(0.54180115)), (13, np.float32(0.013955728))]
# Transcript 128 (34516.txt): [(1, np.float32(0.43790817)), (4, np.float32(0.08735867)), (10, np.float32(0.45085496)), (11, np.float32(0.023829646))]
# Transcript 129 (35542.txt): [(11, np.float32(0.9997428))]
# Transcript 130 (31056.txt): [(4, np.float32(0.8808922)), (11, np.float32(0.119000465))]
# Transcript 131 (34106.txt): [(11, np.float32(0.99539566))]
# Transcript 132 (33626.txt): [(0, np.float32(0.6453861)), (13, np.float32(0.35440764))]
# Transcript 133 (31596.txt): [(5, np.float32(0.9990087))]
# Transcript 134 (35121.txt): [(4, np.float32(0.08686012)), (10, np.float32(0.9031835))]
# Transcript 135 (34571.txt): [(1, np.float32(0.26728356)), (10, np.float32(0.15873586)), (11, np.float32(0.4893605)), (14, np.float32(0.08339716))]
# Transcript 136 (35445.txt): [(4, np.float32(0.27275684)), (7, np.float32(0.7084281)), (11, np.float32(0.018709099))]
# Transcript 137 (35337.txt): [(10, np.float32(0.9998284))]
# Transcript 138 (35336.txt): [(4, np.float32(0.020647902)), (10, np.float32(0.9676544)), (11, np.float32(0.011663936))]
# Transcript 139 (35444.txt): [(4, np.float32(0.9969652))]
# Transcript 167 (33806.txt): [(5, np.float32(0.8947902)), (7, np.float32(0.07473131)), (13, np.float32(0.02398357))]
# Transcript 168 (34831.txt): [(4, np.float32(0.039373018)), (10, np.float32(0.9454412))]
# Transcript 169 (34616.txt): [(1, np.float32(0.64900917)), (4, np.float32(0.025222424)), (7, np.float32(0.128895)), (10, np.float32(0.1667657)), (11, np.float32(0.025782961))]
# Transcript 170 (35534.txt): [(11, np.float32(0.9992447))]
# Transcript 171 (30921.txt): [(8, np.float32(0.99492264))]
# Transcript 172 (30706.txt): [(4, np.float32(0.97849745)), (7, np.float32(0.02107307))]
# Transcript 173 (35440.txt): [(7, np.float32(0.99989104))]
# Transcript 174 (31626.txt): [(5, np.float32(0.25691316)), (10, np.float32(0.25476274)), (11, np.float32(0.48616657))]
# Transcript 175 (35441.txt): [(5, np.float32(0.7165713)), (7, np.float32(0.2809319))]
# Transcript 176 (35327.txt): [(4, np.float32(0.9205287)), (11, np.float32(0.07496492))]
# Transcript 177 (35131.txt): [(4, np.float32(0.031168628)), (10, np.float32(0.90959007)), (11, np.float32(0.05169602))]
# Transcript 178 (34561.txt): [(1, np.float32(0.2591443)), (10, np.float32(0.45415124)), (11, np.float32(0.2833731))]
# Transcript 179 (31586.txt): [(1, np.float32(0.015422908)), (4, np.float32(0.16393024)), (5, np.float32(0.38504353)), (10, np.float32(0.3997586)), (11, np.float32(0.035773672))]
# Transcript 180 (31021.txt): [(11, np.float32(0.99975395))]
# Transcript 181 (33636.txt): [(13, np.float32(0.998584))]
# Transcript 182 (35535.txt): [(11, np.float32(0.99977446))]
# Transcript 183 (33811.txt): [(3, np.float32(0.687785)), (4, np.float32(0.30599025))]

# %%
for i, bow in enumerate(corpus):
    topic_probs = lda_model.get_document_topics(bow)
    top_topic = max(topic_probs, key=lambda x: x[1])  # topic with highest probability
    print(f"{os.path.basename(files[i])}: Topic {top_topic[0]} (weight={top_topic[1]:.2f})")
# Out:
# 34626.txt: Topic 7 (weight=0.51)
# 35538.txt: Topic 11 (weight=1.00)
# 30871.txt: Topic 4 (weight=0.50)
# 34961.txt: Topic 11 (weight=0.98)
# 31616.txt: Topic 12 (weight=0.94)
# 35316.txt: Topic 10 (weight=0.80)
# 34551.txt: Topic 1 (weight=0.47)
# 34586.txt: Topic 10 (weight=0.42)
# 35539.txt: Topic 11 (weight=1.00)
# 31011.txt: Topic 11 (weight=0.82)
# 33821.txt: Topic 13 (weight=1.00)
# 34816.txt: Topic 10 (weight=0.87)
# 31761.txt: Topic 11 (weight=0.55)
# 34631.txt: Topic 1 (weight=0.44)
# 30721.txt: Topic 4 (weight=0.82)
# 34976.txt: Topic 13 (weight=0.65)
# 35315.txt: Topic 7 (weight=0.74)
# 31601.txt: Topic 5 (weight=1.00)
# 34546.txt: Topic 1 (weight=0.55)
# 35116.txt: Topic 10 (weight=0.99)
# 34591.txt: Topic 10 (weight=0.41)
# 33611.txt: Topic 13 (weight=0.97)
# 31006.txt: Topic 11 (weight=0.99)
# 35506.txt: Topic 11 (weight=1.00)
# 33836.txt: Topic 13 (weight=1.00)
# 33826.txt: Topic 13 (weight=1.00)
# 31016.txt: Topic 11 (weight=1.00)
# 34436.txt: Topic 4 (weight=0.49)
# 35066.txt: Topic 5 (weight=0.32)
# 34581.txt: Topic 10 (weight=0.59)
# 34556.txt: Topic 10 (weight=0.45)
# 35338.txt: Topic 10 (weight=1.00)
# 31611.txt: Topic 14 (weight=0.98)
# 35339.txt: Topic 10 (weight=1.00)
# 34966.txt: Topic 11 (weight=1.00)
# 34621.txt: Topic 10 (weight=0.39)
# 33831.txt: Topic 8 (weight=0.67)
# 31001.txt: Topic 11 (weight=0.92)
# 34596.txt: Topic 1 (weight=0.66)
# 34541.txt: Topic 1 (weight=0.97)
# 35312.txt: Topic 10 (weight=1.00)
# 31606.txt: Topic 5 (weight=0.62)
# 30726.txt: Topic 7 (weight=1.00)
# 30861.txt: Topic 7 (weight=1.00)
# 34636.txt: Topic 4 (weight=0.51)
# 34686.txt: Topic 4 (weight=0.38)
# 31701.txt: Topic 4 (weight=0.96)
# 34651.txt: Topic 1 (weight=0.44)
# 35412.txt: Topic 8 (weight=0.49)
# 34526.txt: Topic 1 (weight=0.48)
# 31066.txt: Topic 4 (weight=0.95)
# 34861.txt: Topic 10 (weight=0.66)
# 34691.txt: Topic 1 (weight=0.42)
# 31716.txt: Topic 11 (weight=0.63)
# 34646.txt: Topic 10 (weight=0.46)
# 30971.txt: Topic 11 (weight=0.71)
# 35438.txt: Topic 4 (weight=0.71)
# 35439.txt: Topic 4 (weight=0.74)
# 34096.txt: Topic 4 (weight=0.70)
# 35388.txt: Topic 11 (weight=0.90)
# 34531.txt: Topic 10 (weight=0.39)
# 31071.txt: Topic 4 (weight=0.89)
# 33841.txt: Topic 13 (weight=0.58)
# 35549.txt: Topic 4 (weight=0.59)
# 31061.txt: Topic 4 (weight=0.99)
# 34521.txt: Topic 10 (weight=0.47)
# 34086.txt: Topic 13 (weight=0.99)
# 30961.txt: Topic 4 (weight=0.49)
# 35548.txt: Topic 4 (weight=0.71)
# 34656.txt: Topic 10 (weight=0.50)
# 34871.txt: Topic 10 (weight=0.90)
# 34681.txt: Topic 1 (weight=0.45)
# 31076.txt: Topic 4 (weight=1.00)
# 34536.txt: Topic 1 (weight=0.86)
# 34091.txt: Topic 7 (weight=1.00)
# 35358.txt: Topic 10 (weight=0.72)
# 30976.txt: Topic 11 (weight=0.80)
# 31711.txt: Topic 4 (weight=1.00)
# 34641.txt: Topic 10 (weight=0.77)
# 34866.txt: Topic 10 (weight=0.41)
# 34696.txt: Topic 10 (weight=0.35)
# 31046.txt: Topic 4 (weight=1.00)
# 34506.txt: Topic 4 (weight=0.39)
# 35340.txt: Topic 10 (weight=1.00)
# 35354.txt: Topic 10 (weight=0.97)
# 35355.txt: Topic 10 (weight=0.62)
# 34611.txt: Topic 4 (weight=0.42)
# 34836.txt: Topic 10 (weight=1.00)
# 34826.txt: Topic 10 (weight=1.00)
# 34601.txt: Topic 10 (weight=0.36)
# 35537.txt: Topic 11 (weight=1.00)
# 30936.txt: Topic 4 (weight=0.53)
# 30711.txt: Topic 4 (weight=0.93)
# 34991.txt: Topic 11 (weight=0.91)
# 35443.txt: Topic 7 (weight=0.56)
# 35324.txt: Topic 11 (weight=0.83)
# 35442.txt: Topic 7 (weight=0.61)
# 35126.txt: Topic 10 (weight=1.00)
# 34576.txt: Topic 1 (weight=0.99)
# 31591.txt: Topic 2 (weight=0.88)
# 33621.txt: Topic 13 (weight=0.98)
# 35536.txt: Topic 11 (weight=1.00)
# 33806.txt: Topic 5 (weight=0.90)
# 34831.txt: Topic 10 (weight=0.95)
# 34616.txt: Topic 1 (weight=0.65)
# 35534.txt: Topic 11 (weight=1.00)
# 30921.txt: Topic 8 (weight=0.99)
# 30706.txt: Topic 4 (weight=0.98)
# 35440.txt: Topic 7 (weight=1.00)
# 31626.txt: Topic 11 (weight=0.49)
# 35441.txt: Topic 5 (weight=0.72)
# 35327.txt: Topic 4 (weight=0.92)
# 35131.txt: Topic 10 (weight=0.91)
# 34561.txt: Topic 10 (weight=0.45)
# 31586.txt: Topic 10 (weight=0.40)
# 31021.txt: Topic 11 (weight=1.00)
# 33636.txt: Topic 13 (weight=1.00)
# 35535.txt: Topic 11 (weight=1.00)
# 33811.txt: Topic 3 (weight=0.69)

# %%
transcript_tags = {}

for i, bow in enumerate(corpus):
    topics = lda_model.get_document_topics(bow)
    sorted_topics = sorted(topics, key=lambda x: x[1], reverse=True)
    top_topic = sorted_topics[0][0]
    topic_words = [w for w, _ in lda_model.show_topic(top_topic, topn=5)]
    transcript_tags[os.path.basename(files[i])] = topic_words

df_tags = pd.DataFrame(
    transcript_tags.items(), 
    columns=['Filename', 'Topic Words']
)

# 2. Convert the list of topic words into a comma-separated string for better CSV readability
# e.g., ['jewish', 'community', 'family'] -> "jewish, community, family"
df_tags['Topic Words'] = df_tags['Topic Words'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)
df_tags['ID'] = df_tags['Filename'].str.extract(r'(\d+)\.txt')
df_tags.head()
# Out:
#     Filename                         Topic Words     ID
# 0  34626.txt            said, know, got, one, go  34626
# 1  35538.txt   like, know, really, think, people  35538
# 2  30871.txt      know, people, one, think, time  30871
# 3  34961.txt   like, know, really, think, people  34961
# 4  31616.txt  yeah, forest, think, andrews, well  31616

# %%
output_filename = 'lda_transcript_topics.csv'
df_tags.to_csv(output_filename, index=False)

# %%
from bertopic import BERTopic
from umap import UMAP
import re
from hdbscan import HDBSCAN

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)  # remove punctuation/numbers
    text = ' '.join([w for w in text.split() if w not in stop_words])
    return text

# %%
data_dir = "./test/"  

# Load transcripts
files = glob.glob(os.path.join(data_dir, "*.txt"))

docs = [clean_text(open(f, encoding="utf-8").read()) for f in files]


# Create a smaller, more stable UMAP model
umap_model = UMAP(
    n_neighbors=10,      # reduce neighbor count (default=15)
    n_components=5,     # 2D projection
    min_dist=0.1,       
    metric='cosine', 
    random_state=42
)

hdb = HDBSCAN(
    min_cluster_size=2,    # small clusters allowed
    min_samples=1,         # sensitive to small clusters
    cluster_selection_method="eom",
    prediction_data=True   # << needed for probabilities
)

topic_model = BERTopic(
    embedding_model="all-mpnet-base-v2",
    umap_model=umap_model,
    hdbscan_model=hdb,
    calculate_probabilities=True
)

topics, probs = topic_model.fit_transform(docs)

topic_model.get_topic_info().head()
# Out:
#    Topic  Count                          Name  \
# 0     -1     23      -1_people_one_would_well
# 1      0     10     0_like_know_gender_really
# 2      1     10   1_know_community_irco_asian
# 3      2      9          2_like_gay_im_really
# 4      3      8  3_andrews_people_work_forest
#
#                                       Representation  \
# 0  [people, one, would, well, got, said, go, time...
# 1  [like, know, gender, really, feel, im, dont, y...
# 2  [know, community, irco, asian, family, like, s...
# 3  [like, gay, im, really, people, lesbian, would...
# 4  [andrews, people, work, forest, research, lot,...
#
#                                  Representative_Docs
# 0  [introductory remarks max geier purpose study ...
# 1  [okay today march th im lilith lilith wikstein...
# 2  [name natalia fernndez oregon state university...
# 3  [good morning history oregon state university ...
# 4  [andrews talking little bit worked andrews sin...

# %%
topic_model.visualize_topics()

# %%
import pandas as pd

df = pd.DataFrame({
    "file": files,
    "topic": topics
})

df.head()
# Out:
#                file  topic
# 0  ./test/34626.txt     32
# 1  ./test/35538.txt      0
# 2  ./test/30871.txt     -1
# 3  ./test/34961.txt      7
# 4  ./test/31616.txt     25

# %%
topic_info = topic_model.get_topic_info()
topic_info = topic_info[["Topic", "Name"]]  # keeps only topic number and name

# Merge topic names into df
df = df.merge(topic_info, left_on="topic", right_on="Topic", how="left")
df = df[["file", "topic"]]
df['ID'] = df['file'].str.extract(r'/(\d+)\.txt')
df.head()
# Out:
#                file  topic     ID
# 0  ./test/34626.txt     32  34626
# 1  ./test/35538.txt      0  35538
# 2  ./test/30871.txt     -1  30871
# 3  ./test/34961.txt      7  34961
# 4  ./test/31616.txt     25  31616

# %%
def get_topic_words(topic_num):
    if topic_num == -1:
        return ["outlier"]  # handle unassigned transcripts
    # Returns only the words, not their scores
    return [word for word, _ in topic_model.get_topic(topic_num)]

# %%
df["Top_Words"] = df["topic"].apply(get_topic_words)
df.head()
# Out:
#                file  topic     ID  \
# 0  ./test/34626.txt     32  34626
# 1  ./test/35538.txt      0  35538
# 2  ./test/30871.txt     -1  30871
# 3  ./test/34961.txt      7  34961
# 4  ./test/31616.txt     25  31616
#
#                                            Top_Words
# 0  [time, work, district, kind, al, would, one, g...
# 1  [like, know, gender, really, feel, im, dont, y...
# 2                                          [outlier]
# 3  [students, campus, color, osu, think, student,...
# 4  [climate, change, carbon, ocean, model, econom...

# %%
df.to_csv("bertopic_transcript_topics.csv", index=False)
